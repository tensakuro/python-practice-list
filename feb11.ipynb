# %%
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************
# ...

# %%
num=int(input("enter the number"))

rev=0

while num>0:
    num,d=divmod(num,10)

    rev=rev*10+d
print(rev)
# Out:
# 541

# %%
rows=3
cols=4

i=1

while i<=rows:
    j=1
    while j<=cols:
        print("*",end="")
        j+=1
    i+=1
    print()
# Out:
# ****
# ****
# ****

# %%
rows=3
cols=4

i=1
while i<=rows:
    j=1
    while j<=cols:
        print(i,end="")
        j+=1
    i+=1

    print()
# Out:
# 1111
# 2222
# 3333

# %%
rows=4

i=1

while i<=rows:

    j=1
    while j<=i
    i+=1

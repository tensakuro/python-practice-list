# %%
ip=['Hii','Hello','some','python','Java']

for char in ip:

# %%
s1 = "silentn"
s2 = "listenn"

count1 = {}
count2 = {}

if len(s1) == len(s2):

    for ch in s1:
        count1[ch] = count1.get(ch,0) + 1

    for ch in s2:
        count2[ch] = count2.get(ch,0) + 1
    # print(count1)
    
    
    # print(count2)

    if count1 == count2:
        print("anagram")
    else:
        print("not anagram")

else:
    print("not anagram")
# Out:
# anagram

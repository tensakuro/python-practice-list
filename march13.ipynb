# %%
a=[1,2,3]
b=a
a.append(4)
print(a)
print(b)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
print(0.1 + 0.2 == 0.3)
# Out:
# False

# %%
def add_item(item, lst=[]):
    lst.append(item)
    return lst
print(add_item(1))
print(add_item(2))
# Out:
# [1]
# [1, 2]

# %%
input="python is a very powerful language"

word=""
lst=[]
for letter in input:
    if letter!=" ":
        word+=letter
    else:
        lst.append(word)
        word=""
        
lst.append(word)

        
print(lst)
# Out:
# ['python', 'is', 'a', 'very', 'powerful', 'language']

# %%
# a=[1,2,3,4]
# b=[3,4,1,2]

# if len(a)!=len(b):
#     print("not possible")
# else:
    
    
ip=[1,2,3,4]
rotation=[]
for x in ip:

# %%
def

# %%
nums =[1,2,3]

squares ={x:x **2 for x in nums}

print(squares)

even_oddd_squares ={x :x **2  if x %2 == 0 else x ** 3 for x in nums }



# print(even_osquares)
print(even_oddd_squares)
# Out:
# {1: 1, 2: 4, 3: 9}
# {1: 1, 2: 4, 3: 27}

# %%
words =["apple","banana"]
length_map ={word:len(word) for word in words }

print(length_map)
# Out:
# {'apple': 5, 'banana': 6}

# %%
d = {"a":1,"b":2}

swapped ={v:k  for k,v in d.items()}

print(swapped)
# Out:
# {1: 'a', 2: 'b'}

# %%
nums =[1,2,3,4,5]

parity ={x:"even" if x % 2 == 0 else "odd" for x in nums}

print(parity)
# Out:
# {1: 'odd', 2: 'even', 3: 'odd', 4: 'even', 5: 'odd'}

# %%
text ="banana"

freq ={char:text.count(char) for char in text}

print(freq)
# Out:
# {'b': 1, 'a': 3, 'n': 2}

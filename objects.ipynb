# %%
# class Point:
#     pass

# p=Point()

# # Blank

# print(id(p),id(Point()))

# p.x=3

class  Point:
    pass

class Rectangle:
    pass
box=Rectangle()

print(id(Point())==id(Rectangle()))

print(id(Point()),id(Rectangle()),id(box))

box.width=200
box.length=210

box.corner=Point()

box.corner.x=0
box.corner.y=0

print(box.width)
# Out:
# True
# 2371444912080 2371444912080 2371444900496
# 200

# %%
class Point:
    def __init__(self,x,y) :
        self.x=x
        self.y=y
        
corner=Point(7,8)

print(corner.x,corner.y)

print(id(corner))
# Out:
# 7 8
# 2371444844752

# %%
class Data:
    pass

x=Data()

# %%
class Pair:
    def __init__(self,x,y):
        self.x=x
        self.y=y
    def __str__(self):
        return f"{self.x},{self.y}"
    
p = Pair(3,4)

print(p)
# Out:
# 3,4

# %%
# Task 1: Basic Inheritance
# Create a Parent class Person with method eat().
# Create a Child class Student that inherits Person and has its own method study().
# Create an object of Student and call both methods.

class Parent:
    def __init__(self,name):
        self.name=name
        
    def eat(self):
        print(f"{self.name}  is eating")
        
    def __str__(self):
        return f"{self.name} is introduced"
class Child(Parent):
    def study(self):
        print(f"{self.name} is studying")
        
a=Child("sohel")


print(a)
# print(a.eat())
# print(a.study())

a.eat()
a.study()
# Out:
# sohel is introduced
# sohel  is eating
# sohel is studying

# %%
# Task 2: Inherited Method Usage
# Create a parent class Vehicle with method start().
# Create a child class Car that inherits Vehicle without redefining start().
# Call start() using Car object

class Vehicle:
    def __init__(self,name):
        self.name = name
        
    def start(self):
        return f"{self.name} is starting soon"
    
    def __str__(self):
        return f"name of the vehicle is {self.name}"
    
class Car(Vehicle):
    def rise(self):
        return f"{self.name} is rising fast"

porche = Car("sedan")


porche

print(porche)


porche.start()


porche.rise()
# Out:
# name of the vehicle is sedan
# 'sedan is rising fast'

# %%
# Task 3: Specialized (Specific) Method
# Create a parent class Employee with method work().
# Create a child class Developer that inherits Employee and adds specialized method write_code().
# Call both methods using child object

class Employee:
    def __init__(self,name):
        self.name = name
        
    def work(self):
        return f"{self.name} is currently working"
    
    def __str__(self):
        return f"name of them developer is {self.name}"
    
class Developer(Employee):
    def write_code(self):
        return f"the {self.name} is writing the code"
    
dev = Developer("rajesh")

ded= dev.work()


des=dev.write_code()

print(ded)

print(des)
# Out:
# rajesh is currently working
# the rajesh is writing the code

# %%
# Task 4: Method Overriding
# Create a parent class Animal with method sound() that prints "Animal makes sound".
# Create a child class Dog that overrides sound() to print "Dog barks".
# Call sound() using Dog object.

class Animal:
    def __init__(self,name):
        self.name=name
    def sound(self):
        return "Animal is making sound"
class Child(Animal):
    def sound(self):
        return "dog barks"

    def sound_cat(self):
        return f"{self.name} is meowing"
    
cat = Child("ringa")

cat.sound()

cat.sound_cat()
# Out:
# 'ringa is meowing'

# %%
# Task 5: Simple Overriding
# Create a parent class Shape with method draw() that prints "Drawing shape".
# Create a child class Circle that overrides draw() to print "Drawing circle".
# Call draw() using Circle object.

class Shape:
    def __init__(self,name):
        self.name =  name
        
    def draw(self):
        return "Drawing shape"
    
class Circle(Shape):
    def draw(self):
        return "Drawing circle"
    
cir = Circle("circle")

cir.draw()
# Out:
# 'Drawing circle'

# %%
# Task 6: Constructor Inheritance
# Create a parent class Person with constructor printing "Person created".
# Create a child class Student without constructor.
# Create Student object and observe output.
# # 

class Person:
    def __init__(self):
        print("person created")
    
class Student(Person):
    pass

stud =  Student()
# Out:
# person created

# %%
# Task 7: Child Constructor (No parent call)
# Create a parent class Parent with constructor printing "Parent constructor".
# Create a child class Child with its own constructor printing "Child constructor".
# Create Child object and observe which constructor runs.

class Parent:
    def __init__(self):
        print("Parent constructor")
        
class Child(Parent):
    def __init__(self):
        print("child constructor")
        
c = Child()
# Out:
# child constructor

# %%
# Task 8: Access Parent Variable
# Create parent class Company with variable company_name = "ABC Corp".
# Create child class Employee and print company_name using child object.

class Company:
    company_name = "ABC Corp"
    
class Employee(Company):
    pass

e = Employee()

print(Employee.mro())

print(e.company_name)
# Out:
# [<class '__main__.Employee'>, <class '__main__.Company'>, <class 'object'>]
# ABC Corp

# %%
# types of inheritance
# 1 .single level inheritance
# 2.multi level inheritance
# 3.Hierarchical inheritance
# 4.multiple inheritance
# 5. hybrid inheritance

# MRO
# method resolution order -> c3 linearization algorithm
# diamond problems

# %%
class Dog:
    def speak(self):
        return "Bark"

class Cat:
    def speak(self):
        return "Meow"
    
def make_sound(obj):
    return obj.speak()

make_sound(Dog())
# Out:
# 'Bark'

# %%
class Bank:
    def __init__(self):
        self._balance=0
    def deposit(self,amount):
        if amount > 0:
            self._balance += amount
    def getbalance(self):
        return self._balance
            
b= Bank()

b.deposit(500)

b.getbalance()
# Out:
# 500

# %%
# abstract

from abc import ABC ,abstractmethod
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass
    @abstractmethod
    def perimeter(self):
        pass
    
class Circle(Shape):
    def __init__(self,radius):
        self.radius = radius
    def  area(self):
        return 3.14 * self.radius * self.radius
    def perimeter(self):
        return 2 * 3.14 * self.radius
    
class Rectangle(Shape):
    def __init__(self,length,width):
        self.length = length
        self.width=width
    def area(self):
        return self.length * self.width
    def perimeter(self):
        return 2 * (self.length + self.width)

shapes =[Circle(5),
         Rectangle(4,6)
         ]

for shape in shapes:
    print(type(shape).__name__)
    print(shape.area())
    print(shape.perimeter())
# Out:
# Circle
# 78.5
# 31.400000000000002
# Rectangle
# 24
# 20

# %%
a=[1,2,3]
b=a
b.append(4)

print(a)
# Out:
# [1, 2, 3, 4]

# %%
# diamond problems _ ambiguity

class Problem:
    pass

Problem.mro()
# Out:
# [__main__.Problem, object]

# %%
x =10
print(x)

def add():
    x=x+10
    print(x)
    
add()
# Out:
# 10
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[10], line 8
#       5     x=x+10
#       6     print(x)
# ----> 8 add()
#
# Cell In[10], line 5, in add()
#       4 def add():
# ----> 5     x=x+10
#       6     print(x)
#
# UnboundLocalError: cannot access local variable 'x' where it is not associated with a value

# %%
""" deposit
withdraw
check balance
"""

def deposit():
    amount = int(input('enter your amount'))
    if amount > 0:
        print(f'{amount} is succesfuly credited')
        return amount
    else:
        print('plz enter valid amoint')


def withdraw():
    amount = int(input('enter your  amount'))
    if amount < = balance:
        print
        

def check_balance():
    pass

# %%
class Person:
    name = "sohel"
    
    def show_name(self):
        return f"{self.name}"
class Student(Person):
    roll_no = 21
    def show_student(self):
        return f"{self.roll_no} and {self.name}"
    

p = Person()

p.show_name()


s = Student()

s.show_student()
# Out:
# '21 and sohel'

# %%
class Vehicle:
    def start(self):
        return f"car is starting"
    
class Car(Vehicle):
    def drive(self):
        return f"the person is driving the car"
    
c = Car()

c.start(),c.drive()
# Out:
# ('car is starting', 'the person is driving the car')

# %%
class Company:
    def company_name(self):
        return f"company name is kompany"
    
class Department(Company):
    def dept_name(self):
        return f"department name is dept"
    
class Employee(Department):
    def emp_details(self):
        return f"employee details are sohel"
    
    
e = Employee()

e.company_name(),e.dept_name(),e.emp_details()
# Out:
# ('company name is kompany',
#  'department name is dept',
#  'employee details are sohel')

# %%
class Animal:
    def __init__(self,name):
        self.name = name
        
    def eat(self):
        return f"{self.name} is eating"
    
class Mammal(Animal):
    def walk(self):
        return f"{self.name} is walking"
    
class Dog(Mammal):
    def bark(self):
        return f"{self.name} is barking"
    
    
d = Dog("snoopy")

d.eat(),d.walk(),d.bark()
# Out:
# ('snoopy is eating', 'snoopy is walking', 'snoopy is barking')

# %%
class Account:
    def __init__(self,name,balance):
        self.name =  name
        self.balance = balance
        
    def account_type(self):
        return f"{self.name} has account "

class SavingAcccount(Account):
    def interest(self):
        return f"{self.name} has earned interest {self.balance * 0.05}"
class Overdraft(Account):
    def overdraft(self):
        return f"{self.name} has overdrafted"
    

s = SavingAcccount("sohel",500)

# s.interest()


o = Overdraft("sohel",500)

s.interest(),o.overdraft()


# o.overdraft()
# Out:
# ('sohel has earned interest 25.0', 'sohel has overdrafted')

# %%
class Employee:
    def __init__(self,name,salary):
        self.name = name
        self.salary=salary
        
    def get_salary(self):
        return f"{self.name} has salary of {self.salary}"
    
class Manager(Employee):
    def bonus(self,bonus):
        self.bonus = bonus
        
        return f"bonus of {bonus} is added to account of {self.name}" 
    
class Developer(Employee):
    def coding(self):
        return f"{self.name} is coding"
    
m = Manager("sohel",700)

d = Developer("sohel",700)

x=m.bonus(900),d.coding(),d.get_salary()

print(x)
# Out:
# ('bonus of 900 is added to account of sohel', 'sohel is coding', 'sohel has salary of 700')

# %%
class A:
    
    def __init__(self,name):
        self.name =  name
        
    def show(self):
        return f"{self.name} is showing"
    
class B:
    def show(self):
        return f"name is not showing"
    
class C(A,B):
    pass

c = C("sohel")

c.show()

c.show()

C.mro(),c.show()
# Out:
# ([__main__.C, __main__.A, __main__.B, object], 'sohel is showing')

# %%
class School:
    def __init__(self,name):
        self.name = name
        
    def school_name(self):
        return f"school name is {self.name}"
    
class Teacher(School):
    def subject(self):
        return f"{self.name} is teaching english"
class Student(School):
    def roll_no(self):
        return f"{self.name} roll no is 21"
    
class Monitor(Teacher,Student):
    def duty(self):
        return f"she is doing duty"
    
    
m = Monitor("triveni")

m.school_name(),m.subject(),m.roll_no(),m.duty()
# Out:
# ('school name is triveni',
#  'triveni is teaching english',
#  'triveni roll no is 21',
#  'she is doing duty')

# %%
# bank application

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(1,6,2):
    print(i,end=" ")
# Out:
# 1 3 5

# %%
i=3
while i:
    print(i)
    i-=1
# Out:
# 3
# 2
# 1

# %%
for i in range(5):
    if i==3:
        break
    print(i)
else:
    print("Done")
# Out:
# 0
# 1
# 2

# %%
for i in range(5):
    if i==2:
        continue
    print(i)
# Out:
# 0
# 1
# 3
# 4

# %%
for i in range(3):
    for j in range(i):
        print(i,j)
# Out:
# 1 0
# 2 0
# 2 1

# %%
for i in range(2):
    for j in range(2):
        if j==1:
            break
        print(i,j)
# Out:
# 0 0
# 1 0

# %%
lst=[1,2,3,4]
for x in lst:
    if x%2==0:
        lst.remove(x)
lst
# Out:
# [1, 3]

# %%
lst=[1,2,3,4]
for x in lst[:]:
    if x%2==0:
        lst.remove(x)

lst
# Out:
# [1, 3]

# %%
for i in range(3):
    if i==4:
        break
else:
    print("completed")
# Out:
# completed

# %%
for i in range(5):
    print(i)
    i=100
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i=-3
while i:
    print(i)
    i+=1
# Out:
# -3
# -2
# -1

# %%
for i in range(3):
    if i==1:
        continue
else:
    print("completed")
# Out:
# completed

# %%
for i in range(3):
    for j in range(3):
        if j==1:
            break
        print(i,j)
# Out:
# 0 0
# 1 0
# 2 0

# %%
d={'a':1}

keys=d.keys()

d['b']=2

list(keys)
# Out:
# ['a', 'b']

# %%
num=int(input())

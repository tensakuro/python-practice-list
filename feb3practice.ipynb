# %%
x=20
x-=4
x//=4
x
# Out:
# 4

# %%
x=3
x**=3
x
# Out:
# 27

# %%
s="py"
s*=3
s
# Out:
# 'pypypy'

# %%
s="hi"
t=s
s+="!"
s,t
# Out:
# ('hi!', 'hi')

# %%
lst=[1,2]
lst+=[3,4]
lst
# Out:
# [1, 2, 3, 4]

# %%
a=[1,2]
b=a

a+=[3]

b,a
# Out:
# ([1, 2, 3], [1, 2, 3])

# %%
a=[1,2]
b=a
a=a+[3]

b,a
# Out:
# ([1, 2], [1, 2, 3])

# %%
a=[1,2]
b=a
a+=[3]
a,b
# Out:
# ([1, 2, 3], [1, 2, 3])

# %%
a=[1,2]
b=a
a=a+[3]
a,b
# Out:
# ([1, 2, 3], [1, 2])

# %%
x=5
x/=2
x,type(x)
# Out:
# (2.5, float)

# %%
x=5
x//=2
x,type(x)
# Out:
# (2, int)

# %%
lst=[1]
lst*=3
lst
# Out:
# [1, 1, 1]

# %%
lst=[[0]]
lst*=3

id(lst[0]),id(lst[1]),id(lst[2])
# Out:
# (2386432801536, 2386432801536, 2386432801536)

# %%
a=[1,2,3]
b=a
a[:]+=[4]
a,b
# Out:
# ([1, 2, 3, 4], [1, 2, 3, 4])

# %%
a=[1,2,3]
b=a
a=a[:]+[4]

a,b
# Out:
# ([1, 2, 3, 4], [1, 2, 3])

# %%
t=([1],)
t[0]*=3
t
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 t=([1],)
# ----> 2 t[0]*=3
#       3 t
#
# TypeError: 'tuple' object does not support item assignment

# %%
5 |3
# Out:
# 7

# %%
6 <<1
# Out:
# 12

# %%
7 &1
# Out:
# 1

# %%
6&1
# Out:
# 0

# %%
9^9
# Out:
# 0

# %%
9^0
# Out:
# 9

# %%
x=10
x=x & (x-1)

x
# Out:
# 8

# %%
x=10
y=20

m=x if x>y else y
m
# Out:
# 20

# %%
n=7
res="even" if n%2==0 else "odd"

res
# Out:
# 'odd'

# %%
a=5
b=10

c=a+1 if a >b else b+1

c
# Out:
# 11

# %%
x=0
y=100
z=x if x else y
z
# Out:
# 100

# %%
x=5
y=10

z=0 if x>y else (1 if x==y else 2)
z
# Out:
# 2

# %%
x=5
y=10
z=x if x >y else(y if y>0 else 0)
z
# Out:
# 10

# %%
3 in [1,2,3,4]
# Out:
# True

# %%
[1,2] in [1,2,3,4]
# Out:
# False

# %%
(1,2) in [(1,2),(3,4)]
# Out:
# True

# %%
"a" in "cat"
# Out:
# True

# %%
"at" in "cat"
# Out:
# True

# %%
"cta" in "cat"
# Out:
# False

# %%
3 in {1,2,3}
# Out:
# True

# %%
"a" in "banana"
# Out:
# True

# %%
"an" in "banana"
# Out:
# True

# %%
"baN" in "banana"
# Out:
# False

# %%
[1,2] in [[1,2],[3,4]]
# Out:
# True

# %%
2 in [[1,2],[3,4]]
# Out:
# False

# %%
(1,2) in [(1,2),(3,4)]
# Out:
# True

# %%
"" in "abc"
# Out:
# True

# %%
x=3
x in range(1,5)
# Out:
# True

# %%
x=[1,2,3]
x in x
# Out:
# False

# %%
5>3
# Out:
# True

# %%
5<3
# Out:
# False

# %%
5==3
# Out:
# False

# %%
if 10:
    print("runs")
# Out:
# runs

# %%
x=10
if x>5:
    print("greater")
# Out:
# greater

# %%
if x>5:
    print("greater")
else:
    print("smaller")
# Out:
# greater

# %%
x=7
if x >10:
    print("big")
elif x>5:
    print("medium")
else:
    print("small")
# Out:
# medium

# %% [markdown]
# x=7
# 3<x<10

# %%
x=7

3<x<10
# Out:
# True

# %%
x=int(input("enter the number: "))

if x>0:
    print(f"{x} is a positive number")
# Out:
# 8 is a positive number

# %%
x=int(input("enter the number :"))

if x==0:
    print(f"{x} is a zero")
else:
    print(f"{x} is not zero")
# Out:
# 9 is not zero

# %%
a=int(input())

b=int(input())

if a>b:
    print(f"{a} is greater than {b}")
else:
    print(f"{b} is greater than {a}")
# Out:
# 4 is greater than 2

# %%
year=int(input("enter the year :"))

if year%400==0 and year%4==0:
    print("leap year")
elif year%100==0:
    print("not leap year")
else:
    print("not leap year")
# Out:
# leap year

# %%
if [0]:
    print("true")
else:
    print("False")
# Out:
# true

# %%
bool([])
# Out:
# False

# %%
bool(())
# Out:
# False

# %%
bool("0")
# Out:
# True

# %%
x=[] or {} or () or 5
x
# Out:
# 5

# %%
10 and 0 and 5
# Out:
# 0

# %%
10 and 20 and 30
# Out:
# 30

# %%
0 and 1 or 2
# Out:
# 2

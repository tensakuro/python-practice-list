# %%
3 and 0
# Out:
# 0

# %%
my_items=['a','b','c']

# for i in range(len(my_items)):
#     print(my_items[i])

# for item in my_items:
#     print(item)

for i,item in enumerate(my_items):
    print(f"{i}:{item}")
# Out:
# 0:a
# 1:b
# 2:c

# %%
emails={
    'Bob':'bob@example.com',
    'Alice':'alice@example.com',
}

for name,email in emails.items():
    print(f"{name}->{email}")
# Out:
# Bob->bob@example.com
# Alice->alice@example.com

# %%
squares=[x*x for x in range(10)]

squares
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
even_squares=[x*x for x in range(10) if x%2==0 and x>0]
even_squares
# Out:
# [4, 16, 36, 64]

# %%
if are_friends:
    print()

# %%
price=int(input("enter the price"))

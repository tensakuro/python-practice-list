# %%
class Dog:
    def __init__(self,name,breed,age) -> None:
        self.name=name
        self.breed=breed
        self.age=age
        
    def bark(self):
        print(f"{self.name} says woof")
    
dog1=Dog("miles","german shepherd",4)
dog2=Dog("mural","pug",2)

print(dog2.bark())




# print(dog1)
# print(dog1.name)
        
    

# dog1=Dog()
# dog2=Dog()
# print(id(Dog))
# print((dog1,dog2))

# print(id(dog1))

# print(id(dog2))

# print(Dog)
# Out:
# mural says woof
# None

# %%
class Student:
    insti="10l"
    
    def __init__(self,name,batch) -> None:
        self.name=name
        self.batch=batch
    
s1=Student("sohel","d9")
s2=Student("harish","d9")


print(s1)
print(s2)

s1.name

print(f"{s1.name} :{s1.insti}")
# Out:
# ...
# sohel :10l

# %%
class Bank_account:
    bank_name="sbi"

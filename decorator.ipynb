# %%
# functions are objects
def f():
    return "hi"

g =f
g()
# Out:
# 'hi'

# %%
# functions can take functions
def operate(func):
    return func()

operate(f)
# Out:
# 'hi'

# %%
# function can return functions

def outer():
    def inner():
        return "inside"
    return inner

fn =outer()
fn()
# Out:
# 'inside'

# %%
# execution order



@A 
@B 
def f():
    pass

# %%
units=int(input('enter the units'))

# %%
str1="hello"
str2="something great"

str1.upper()
str1.lower()
str1.isupper()

str1.islower()

str1.capitalize()

str2.capitalize()

str2.title()
# Out:
# 'Something Great'

# %%
list1=[4,6,7,8,12,14,16]

op=list1[::-1]

op

list1[::2]
# Out:
# [4, 7, 12, 16]

# %%
a=[3,1,2]
x=a.sort()
x
a
# Out:
# [1, 2, 3]

# %%
a=[1,2,2]
a.index(2,start:0,end:len(a))
